# %%
# !pip install tensorflow keras
# !pip install pillow
# !pip install tensorflow-model-optimization tf-keras
# !pip install scikit-learn

# %%
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adamax
# Out:
# 2024-12-07 13:19:38.144010: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-07 13:19:38.151930: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733573978.159704    3031 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733573978.162438    3031 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 13:19:38.174377: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Define paths
dataset_dir = 'dataset_ab'
train_dir = dataset_dir 
val_dir = dataset_dir  # You can split data into train/val if needed

# Image parameters
img_height, img_width = 96, 96  # Adjust as needed
batch_size = 32

def to_grayscale(image):
    # image = tf.image.rgb_to_grayscale(image)
    return image

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=to_grayscale,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=to_grayscale
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'  # Use 'binary' for 2 classes
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical'  # Use 'binary' for 2 classes
)
# Out:
# Found 3000 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.

# %%
# Load pre-trained MobileNetV3Small
base_model = MobileNetV3Small(
    input_shape=(img_height, img_width, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = True

x=BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(32, kernel_regularizer = regularizers.l2(l2 = 0.016),activity_regularizer=regularizers.l1(l1 = 0.006),
                bias_regularizer=regularizers.l1(l1 = 0.006) ,activation='relu')(x)
x=Dropout(rate=.4, seed=69)(x)       

output=Dense(2, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
model.compile(Adamax(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy']) 

model.fit(
    train_generator,
    epochs=epochs,  # Train for a few more epochs
    validation_data=val_generator
)

# %%
from tensorflow.keras import saving

# Save the model
try:
    #model.save("model_outputs/mobilenetv3_simple_ab.keras")    
except:
    @saving.register_keras_serializable()
    def F1_score(y_true, y_pred): #taken from old keras source code
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        recall = true_positives / (possible_positives + K.epsilon())
        f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
        return f1_val
    
    model = tf.keras.models.load_model('model_outputs/mobilenetv3_simple_ab.keras')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

# Define a representative dataset generator
def representative_dataset():
    dataset_list = tf.data.Dataset.list_files(dataset_dir + '/*/*')
    for i in range(2000):
        image_path = next(iter(dataset_list)).numpy().decode("utf-8")
        img = load_img(image_path, target_size=(img_height, img_width))
        img = img_to_array(img)
        img = img / 255.0
        img = np.expand_dims(img, axis=0)
        yield [img.astype(np.float32)]
        
# Create the TFLite converter with INT8 quantization and representative dataset
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]  
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8
converter.representative_dataset = representative_dataset
tflite_model = converter.convert()   

# Save the TFLite model
with open('model_outputs/mobilenetv3_simple_ab.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp047bqjq7/assets
# INFO:tensorflow:Assets written to: /tmp/tmp047bqjq7/assets
# Saved artifact at '/tmp/tmp047bqjq7'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   139718834305168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834303632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834305936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834304976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834304784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834305552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379766032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718834306128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379766800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379767184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379768336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379768528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379769104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379766416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379770448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379770640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379770256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379769680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379771024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379772368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379772560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379772176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379771408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379772944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379774288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379774480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379774096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379773328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379774864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379776208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379776400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379776016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379775248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379776784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379778128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379778320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379777936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379777168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379778704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379780048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379780240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379779856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379779088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379780624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379781968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379781776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379781584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379779472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380192208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380193552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380193744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380193360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380192784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380194128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380195472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380195664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380195280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380194512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380196048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380197200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380197392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380197968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380196432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380198736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380198928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380198544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380199312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380200656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380200848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380200464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380199696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380201232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380202576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380202768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380202384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380201616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380203152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380204304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380204496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380205072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380205264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380206032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380206224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380205840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380205456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380206608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380207952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380207760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380207568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718380203536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378471696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378473232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378473424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378473040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378472272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378473808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378475152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378475728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378475920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378476688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378476880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378476496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378476112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378477264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378478608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378478800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378478416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378485904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378898256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378899216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378899408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378899984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378900176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378900944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378901136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378900752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378900368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378901520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378902864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378903056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378902672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378901904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378903440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378904784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378904976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378904592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378903824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378905360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378906512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378906704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378907280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378907472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378908240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378908432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378908048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378907664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378908816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378910160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378910352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378909968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378909200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378910736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378912080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378912272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378911888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378911120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378912656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378906896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378913040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718378913424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379356624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379357968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379358160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379357776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379357200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379358544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379359888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379360080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379359696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379358928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379361808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379362000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379361616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379360848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379363920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379369872: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   139718379368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718379371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1733574105.206987    3031 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1733574105.207021    3031 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2024-12-07 13:21:45.207397: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp047bqjq7
# 2024-12-07 13:21:45.210902: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-12-07 13:21:45.210913: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp047bqjq7
# I0000 00:00:1733574105.247419    3031 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2024-12-07 13:21:45.254196: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-12-07 13:21:45.518329: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp047bqjq7
# 2024-12-07 13:21:45.580382: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 372987 microseconds.
# 2024-12-07 13:21:45.631588: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

# Testing block
def test_image(image_path):
    """
    Loads an image, preprocesses it, and predicts its class using the trained model.

    Args:
        image_path (str): Path to the image file.
    """
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)  # Add batch dimension

    prediction = model.predict(img)
    class_index = np.argmax(prediction)
    class_labels = list(train_generator.class_indices.keys())  # Get class labels
    confidence = np.max(prediction)  # Get the highest probability

    print(prediction);
    print(class_labels);
    print("Predicted class: %s (confidence: %.2f)" % (class_labels[class_index], confidence))


# Example usage
test_image('test_inputs/cat2.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.8328236 0.1671764]]
# ['cat', 'not_cat']
# Predicted class: cat (confidence: 0.83)

# %%
from tensorflow.lite.python.util import convert_bytes_to_c_source

file_name = 'model'
source_text, header_text = convert_bytes_to_c_source(tflite_model,  file_name)

with  open('model_outputs/' + file_name + '.h',  'w')  as  file:
    file.write(header_text)

with  open('model_outputs/' + file_name + '.cc',  'w')  as  file:
    file.write(source_text)
