# %%
# !pip install tensorflow keras
# !pip install pillow
# !pip install tensorflow-model-optimization tf-keras
# !pip install scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: keras in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras) (0.13.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: pillow in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (11.0.0)
# Requirement already satisfied: tensorflow-model-optimization in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: tf-keras in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: absl-py~=1.2 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow-model-optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow-model-optimization) (1.16.0)
# Requirement already satisfied: tensorflow<2.19,>=2.18 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tf-keras) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorflow<2.19,>=2.18->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.19,>=2.18->tf-keras) (0.44.0)
# Requirement already satisfied: rich in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.19,>=2.18->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<2.19,>=2.18->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.19,>=2.18->tf-keras) (0.1.2)
# Requirement already satisfied: scikit-learn in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages (from scikit-learn) (3.5.0)

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
# Define paths
dataset_dir = 'dataset'
train_dir = dataset_dir 
val_dir = dataset_dir  # You can split data into train/val if needed

# Image parameters
img_height, img_width = 96, 96  # Adjust as needed
batch_size = 32


# Data augmentation
train_datagen = ImageDataGenerator()
val_datagen = ImageDataGenerator()

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    color_mode='rgb',
    batch_size=batch_size,
    class_mode='categorical'  # Use 'binary' for 2 classes
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    color_mode='rgb',
    batch_size=batch_size,
    class_mode='categorical'  # Use 'binary' for 2 classes
)
# Out:
# Found 3000 images belonging to 3 classes.
# Found 3000 images belonging to 3 classes.

# %%
from tensorflow.keras import saving

@saving.register_keras_serializable()
def F1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

model = tf.keras.models.load_model('outputs/out_v4.keras')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

# Define a representative dataset generator
def representative_dataset():
    dataset_list = tf.data.Dataset.list_files(dataset_dir + '/*/*')
    for i in range(100):
        image_path = next(iter(dataset_list)).numpy().decode("utf-8")
        img = load_img(image_path, target_size=(img_height, img_width))
        img = img_to_array(img)
        img = np.expand_dims(img, axis=0)
        yield [img.astype(np.float32)]
        
# Create the TFLite converter with INT8 quantization and representative dataset
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]  
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8
converter.representative_dataset = representative_dataset
tflite_model = converter.convert()   

# Save the TFLite model
with open('outputs/mobilenetv4_model_int8.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpopta02xo/assets
# INFO:tensorflow:Assets written to: /tmp/tmpopta02xo/assets
# Saved artifact at '/tmp/tmpopta02xo'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 96, 96, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   140366445920720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445921872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445922256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445921680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445921104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445922064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445924560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445924752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445924368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445923792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445925136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445926288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445927056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445920528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445928400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445928592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445928208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445927632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445928976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445930320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445930512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445930128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445929360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445930896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445932240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445932432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445932048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445931280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445932816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445934160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445934352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445933968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445933200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445934736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445936080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445933584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445935888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445935120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366445936272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447236240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447238160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447237200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447238736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447239888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447240656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447241040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447243344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447245456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447245648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447246032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447240272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447246800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447509776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447511120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447511312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447510928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447510352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447511696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447513040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447513232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447512848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447512080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447513616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447514960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447515152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447514768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447514000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447515536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447516880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447517456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447517648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447518224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447517840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447520336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447520144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447519376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447520912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447522256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447522448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447522064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447521296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447522832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447523984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447524176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447524752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447524944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447525712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447525520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447525328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366447521680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044595984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044596176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044595792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044594448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044596560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044597904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044598096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044597712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044596944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044598480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044599632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044599824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044600400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044600592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044601168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044601936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044603280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044603472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044602320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044605200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044605392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044604240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044605776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044606928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044607120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044607696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044607888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044608656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044608848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044608464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044608080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044609232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044610384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043972048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044607312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366044606160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043972240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043973584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043973776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043973392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043972432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043974160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043975312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043975504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043976080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043976272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043977040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043977232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043976848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043976464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043977616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043978960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043979152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043978768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043978000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043979536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043980880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043981072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043980688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043979920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043981456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043982608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043982800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043983376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043983568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043984336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043984528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043984144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043983760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043984912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043986256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043986448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043986064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043985296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043985680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043987216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043982992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140366043986832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140364861735760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140364861736912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140364861734992: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   140364861736144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140364861738064: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/nikolai/anaconda3/envs/train_p11/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1733267561.777776     408 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1733267561.778019     408 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2024-12-04 00:12:41.779074: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpopta02xo
# 2024-12-04 00:12:41.785747: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-12-04 00:12:41.785761: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpopta02xo
# 2024-12-04 00:12:41.870878: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-12-04 00:12:42.148106: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpopta02xo
# 2024-12-04 00:12:42.209906: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 430856 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: UINT8, output_inference_type: UINT8

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import numpy as np

# Testing block
def test_image(image_path):
    """
    Loads an image, preprocesses it, and predicts its class using the trained model.

    Args:
        image_path (str): Path to the image file.
    """
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)  # Add batch dimension

    prediction = model.predict(img)
    class_index = np.argmax(prediction)
    class_labels = list(train_generator.class_indices.keys())  # Get class labels
    confidence = np.max(prediction)  # Get the highest probability

    print(prediction);
    print(class_labels);
    print("Predicted class: %s (confidence: %.2f)" % (class_labels[class_index], confidence))


# Example usage
test_image('cat-test.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# [[0.761813   0.14891128 0.08927564]]
# ['cat', 'elephant', 'horse']
# Predicted class: cat (confidence: 0.76)

# %%
# Verify the TFLite model
interpreter = tf.lite.Interpreter(model_path="outputs/mobilenetv4_model_int8.tflite")
interpreter.allocate_tensors()

def test_image_tflite(image_path):
    categories = np.array(["cat", "elephant", "horse"]);
    
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    input_scale, input_zero_point = input_details[0]['quantization']
    
    # Load the custom image
    img = load_img(image_path, target_size=(img_height, img_width))
    img = img_to_array(img)
    
    image_array_uint8 = (img / input_scale + input_zero_point).astype("uint8")
    image_array_uint8 = np.expand_dims(image_array_uint8, axis=0)  # Add batch dimension
    
    # Set the input tensor
    interpreter.set_tensor(input_details[0]['index'], image_array_uint8)
    
    # Invoke the model
    interpreter.invoke()
    
    # Get the predictions
    predictions = interpreter.get_tensor(output_details[0]['index'])
    print(predictions)
    print("Predictions: %s with confidence %.2f" % (categories[predictions.argmax()], (predictions[0][predictions.argmax()])/255*100))

test_image_tflite("elephant-test.jpg")
# Out:
# [[ 27 206  23]]
# Predictions: elephant with confidence 80.78

# %%
from tensorflow.lite.python.util import convert_bytes_to_c_source

file_name = 'model'
source_text, header_text = convert_bytes_to_c_source(tflite_model,  file_name)

with  open('outputs/' + file_name + '.h',  'w')  as  file:
    file.write(header_text)

with  open('outputs/' + file_name + '.cc',  'w')  as  file:
    file.write(source_text)
